# %%
print("hello world!")
names = ("ahsan","hashim","azam","saifullah","saeed")  
(name1,name2,name3,name4,name5) = ('ahsan','hashim','azam','saifullah','saeed')
# Out:
# hello world!

# %%
print(name3)
print(f"is taha in tuple:" , 'taha' in names)
# Out:
# azam
# is taha in tuple: False

# %%
num1 , num2 = 1 , 2
num1 ,num2 = num2 , num1
print(f"number one is:",{num1}, "number two is:",{num2})
# Out:
# number one is: {2} number two is: {1}
