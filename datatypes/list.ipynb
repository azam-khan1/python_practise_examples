# %%
names = ["asad","azam","hashim","ahsan","saifullah"]
print(f"The Names are: ",names)
# Out:
# The Names are:  ['asad', 'azam', 'hashim', 'ahsan', 'saifullah']

# %%
names.append("sajid")
print(f"The Names are: ",names)
# Out:
# The Names are:  ['asad', 'azam', 'hashim', 'ahsan', 'saifullah', 'sajid']

# %%
names.sort()
print(f"Sorted Names are: ",names )
# Out:
# Sorted Names are:  ['ahsan', 'asad', 'azam', 'hashim', 'saifullah', 'sajid']
