# %%
dict1  = dict(name="john",age="20",gender="male")
print(dict1)
dict1["activity"]= "student"
print(dict1)
# Out:
# {'name': 'john', 'age': '20', 'gender': 'male'}
# {'name': 'john', 'age': '20', 'gender': 'male', 'activity': 'student'}

# %%
del dict1["age"] 
print(dict1.keys())
print(dict1.values())
print(dict1.items())
# Out:
# dict_keys(['name', 'gender', 'activity'])
# dict_values(['john', 'male', 'student'])
# dict_items([('name', 'john'), ('gender', 'male'), ('activity', 'student')])

# %%
print(dict1.get('age','not found'))
find_age = dict1.get('age','not found')
print(f"Is there age in dict1: {find_age}")
# Out:
# not found
# Is there age in dict1: not found

# %%
countries =[
{
    "italy": ["rome","venice","milan"],
    "france": ["paris","lyon","marseille"],
    "hungary": ["budapest","debrecen","szeged"],
},
{
    "germany": {"wanted to visit": ["berlin","munich","hamburg"]},
    "italy": {"wanted to visit": ["rome","venice","milan"]},
    "france": {"wanted to visit": ["paris","lyon","marseille"]},
}
]
print(countries[0].keys())
print()
# Out:
# dict_keys(['italy', 'france', 'hungary'])
