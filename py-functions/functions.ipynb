# %%
def student_data():
    std = input("Enter std name: ")
    std_roll_no = int(input("Enter std roll_no: "))
    std_batch = int(input("Enter std batch: "))
    std_semester = int(input("Enter std semester: "))
    std_program = input("Enter std program: ")
    print(std , std_roll_no , std_semester , std_program , sep = "\n")

student_data()

# %%
student_data()
def student():
    std = input("Enter your Name: ")
    print(f"student name = {std}")
    def student_roll_no():
        student_roll_no = int(input("Enter student roll no: "))
        print(f"student roll no is :{student_roll_no}")
    student_roll_no()
student()

# %%
def temperature (c_temp,f_temp):
    cel_temp = (f_temp - 32) * 5 / 9 
    far_temp = (c_temp * 9 / 5) + 32 
    return cel_temp ,  far_temp

print(temperature(15,95))
# Out:
# (35.0, 59.0)

# %%
items = {}
def total_items ():
    item_name = input("enter item name: ")
    item_price = int(input("enter item price: "))
    items[item_name] = item_price
    print("items are: ", list(items.keys()))
    print("total amount is: ",sum(list(items.values())))
total_items()

# %%
items = {}

def total_items():
    while True:
        item_name = input("Enter item name (or type 'exit' to stop): ")
        if item_name.lower() == 'exit':
            break
            
        try:
            item_price = int(input("Enter item price: "))
            items[item_name] = item_price
            
            print("Current items:", list(items.keys()))
            print("Total amount is:", sum(items.values()))
            print("-" * 20)
        except ValueError:
            print("Oops! Please enter a whole number for the price.")

total_items()

# %%
def len_of_function (list):
    print(list)
    return len(list)

len_of_function([1,2,4,5,6,7,8,9])
# Out:
# [1, 2, 4, 5, 6, 7, 8, 9]
# 8

# %%
def pkr_usd (pkr):
    return(pkr * float(278.31))

pkr_usd(17)
# Out:
# 4731.27
