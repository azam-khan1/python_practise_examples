# %%
name = input("Enter you name: ")
for i in range(5):
    print(f"Welcome to our Hotel {name}!")
# Out:
# Welcome to our Hotel Azam!
# Welcome to our Hotel Azam!
# Welcome to our Hotel Azam!
# Welcome to our Hotel Azam!
# Welcome to our Hotel Azam!

# %%
for num in range(1,10+1):
    print(f"Serving to #{num}")
# Out:
# Serving to #1
# Serving to #2
# Serving to #3
# Serving to #4
# Serving to #5
# Serving to #6
# Serving to #7
# Serving to #8
# Serving to #9
# Serving to #10

# %%
orders = ["azam","saeed","saif","hashim","ahsan"]
for name in orders:
    if name == "azam":
        print(f"order for {name}")
# Out:
# order for azam

# %%
orders = ["azam","saeed","saif","hashim","ahsan"]
for name in orders:
    print(f"order for {name}")
# Out:
# order for azam
# order for saeed
# order for saif
# order for hashim
# order for ahsan

# %%
orders = ["azam","saeed","saif","hashim","ahsan"]
for idx,orders in enumerate(orders,start =1):
    print(f"{idx}: order for {orders}")
# Out:
# 1: order for azam
# 2: order for saeed
# 3: order for saif
# 4: order for hashim
# 5: order for ahsan

# %%
orders = ["azam","saeed","saif","hashim","ahsan"]
bills = [100,150,200,100,200]
for name,amount in zip(orders,bills):
    print(f"{name} paid {amount} rupees")
# Out:
# azam paid 100 rupees
# saeed paid 150 rupees
# saif paid 200 rupees
# hashim paid 100 rupees
# ahsan paid 200 rupees
