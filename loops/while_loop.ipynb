# %%
tem = 40
while (tem < 100):
    tem+= 15
    print(f"Current temperature is :{tem}")
print("Water Boiled")
# Out:
# Current temperature is :55
# Current temperature is :70
# Current temperature is :85
# Current temperature is :100
# Water Boiled

# %%
tem = 40
while (tem < 100):
    print(f"Current temperature is :{tem}")
    tem+= 15
print("Water Boiled")
# Out:
# Current temperature is :40
# Current temperature is :55
# Current temperature is :70
# Current temperature is :85
# Water Boiled

# %%
orders = ["azam","saeed","saif","hashim","ahsan"]
bills = [100,150,200,100,200]
for name  in orders:
    if name == "Qasim":                 #if  i change the name to 'Saeed' then condition become true and print run then break and 
        print(f"{name} will pay")       #if Qasim is entered no condition is true then else will run other wise not run.
        break
else:
    print(f"all payed the bill")
# Out:
# all payed the bill
