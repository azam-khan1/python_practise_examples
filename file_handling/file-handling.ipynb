# %%
f = open("demo.txt","r")
data = f.read()
print(data)
print(type(data))
f.close()
# Out:
# hello!
# today i am studying how to handle file in python.
# today is my first lecture related to this on date 27/04/2026 and is going very good.
# day second of learning file handling in python.
# <class 'str'>

# %%
d = open("demo.txt","a")
d.write("day second of learning file handling in python")
d.close
# Out:
# <function TextIOWrapper.close()>

# %%
d =  open("demo.txt","r")
line1 = d.readline()
print(line1)
d.close()
# Out:
# hello!

# %%
d = open("demo.txt","a+")
data = d.write("\ntoday is my day 3 of learning file handling in python")
print(data)
d.close()
# Out:
# 54
