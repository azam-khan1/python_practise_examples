# %%
def sum (n):
    if n == 0:
        return 0
    return (n + sum(n-1))
print(sum(5))
# Out:
# 15

# %%
marvel = ["ironman", "captain", "hulk", "antman", "mario"]
def display (n):
    if n <0:
        return ""
    print( marvel[n])
    display(n - 1)

display(len(marvel)-1)
# Out:
# mario
# antman
# hulk
# captain
# ironman
